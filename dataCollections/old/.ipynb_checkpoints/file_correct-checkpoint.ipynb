# %%
import pandas as pd
import numpy as np
import time

# %%
class DCModel:

    def __init__(self, path):
        self.df = pd.read_csv(path, sep='\t')
        self.name = self.df['name'].tolist()
        self.all_name = self.df['name'].tolist() + self.aliases()

    def __len__(self):
        return self.df.__len__()

    def names(self):
        return self.name

    def aliases(self):
        al = []
        for i in self.df['aliases'].unique():
            if not pd.isna(i):
                al += i.split('|')
        return al

    def has(self, name):
        if name in self.all_names:
            return True
        else:
            return False

    def find(self, keyword):
        # fuzzy match
        r_n = self.df[self.df['name'].str.find(keyword) == 0]
        r_a = self.df[self.df['aliases'].str.find(keyword) == 0]
        if r_n.__len__() != 0:
            return r_n['name'].values[0]
        elif r_a.__len__() != 0:
            return r_a['name'].values[0]
        else:
            return None

    def find_exact(self, keyword):
        # exact match
        r_n = self.df[self.df['name'] == keyword]
        r_a = self.df[self.df['aliases'] == keyword]
        if r_n.__len__() != 0:
            return r_n['name'].values[0]
        elif r_a.__len__() != 0:
            return r_a['name'].values[0]
        else:
            return None
        
    def add(self, name, status='new', comment=np.nan, aliases=np.nan):
        self.df = self.df.append({'name': str(name),
                                  'status': status,
                                  'comment': comment,
                                  'aliases': aliases
                                  }, ignore_index=True).copy()
    
    def to_csv(self, path):
        self.df.to_csv('path', sep='\t', index=False)
        

    
celllines = DCModel('../celllines.txt')

# %%
class DCJournal:

    def __init__(self, path):
        self.df = pd.read_csv(path, sep='\t')
        self.name = self.df['name'].tolist()

    def __len__(self):
        return self.df.__len__()

    def names(self):
        return self.name

    def has(self, name):
        if name in self.name:
            return True
        else:
            return False

    def find(self, keyword):
        # fuzzy match
        r_n = self.df[self.df['name'].str.find(keyword) == 0]
        if r_n.__len__() != 0:
            return r_n['name'].values[0]
        else:
            return None
        
    def find_exact(self, keyword):
        # exact match
        r_n = self.df[self.df['name'] == keyword]
        if r_n.__len__() != 0:
            return r_n['name'].values[0]
        else:
            return None

    def add(self, name, issn=np.nan, impact_factor=np.nan):
        self.df = self.df.append({'name': str(name),
                                  'issn': issn,
                                  'impact_factor': impact_factor
                                  }, ignore_index=True).copy()
    
    def to_csv(self, path):
        self.df.to_csv('path', sep='\t', index=False)
        
journal = DCJournal('../journals.txt')

# %%
journal.find('Nucleic')
# Out:
# 'Nucleic Acids Res.'

# %%
class DCPaper:

    def __init__(self, path):
        self.df = pd.read_csv(path, sep='\t')
        self.pmid = self.df['pmid'].tolist()

    def __len__(self):
        return self.df.__len__()

    def has(self, pmid):
        if pmid in self.pmid:
            return True
        else:
            return False

#     def find(self, keyword):
#         # fuzzy match
#         r_n = self.df[self.df['name'].str.find(keyword) == 0]
#         if r_n.__len__() != 0:
#             return r_n['name'].values[0]
#         else:
#             return None

    def find_exact(self, keyword):
        # exact match
        r_n = self.df[self.df['pmid'] == keyword]
        if r_n.__len__() != 0:
            return list(r_n.T.to_dict().items())[0][1]
        else:
            return None

    def add(self, pmid=np.nan, unique_id=np.nan, title=np.nan,
            reference=np.nan, abstract=np.nan, pub_date=np.nan,
            collect_date=np.nan, authors=np.nan, last_auth_email=np.nan,
            journal=np.nan, status='new', lab=np.nan,
            pub_summary=np.nan, comment=np.nan):
        self.df = self.df.append({'pmid': str(pmid),
                                  'unique_id': unique_id,
                                  'title': title,
                                  'reference': reference,
                                  'abstract': abstract,
                                  'pub_date': pub_date,
                                  'collect_date': collect_date,
                                  'authors': authors,
                                  'last_auth_email': last_auth_email,
                                  'journal': journal,
                                  'status': status,
                                  'lab': lab,
                                  'pub_summary': pub_summary,
                                  'comment': comment,
                                  }, ignore_index=True).copy()

    def to_csv(self, path):
        self.df.to_csv(path, sep='\t', index=False)
        
papers = DCPaper('../papers.txt')

# %%
pmid	unique_id	title	reference	abstract	pub_date	collect_date	authors	last_auth_email	journal	status	lab	pub_summary	comment

# %%
papers.find_exact('20508144')
# Out:
# {'pmid': '20508144',
#  'unique_id': 'GSE20478',
#  'title': 'A global role for KLF1 in erythropoiesis revealed by ChIP-seq in primary erythroid cells.',
#  'reference': 'Tallack MR, et al. A global role for KLF1 in erythropoiesis revealed by ChIP-seq in primary erythroid cells. Genome Res. 2010',
# ...

# %%
papers.df
# Out:
#           pmid  unique_id                                              title  \
# 0     20208068   GSE17937  Comparing genome-wide chromatin profiles using...
# 1     20690147   GSE21665  Global analysis of in vivo EGR1-binding sites ...
# 2     21152096   GSE18481  Efficient double fragmentation ChIP-seq provid...
# 3     20508144   GSE20478  A global role for KLF1 in erythropoiesis revea...
# 4     21423270   GSE26005  The human TTAGGG repeat factors 1 and 2 bind t...
# ...        ...        ...                                                ...
# 4110  31434493  200131212  Epigenetic Regulation of Vascular Smooth Muscl...
# 4111  31786140  200114981  HOTTIP lncRNA Promotes Hematopoietic Stem Cell...
# 4112  31775036  200107408  MLL1 Inhibition and Vitamin D Signaling Cooper...
# 4113  31792383  200128466  Eomes and Brachyury control pluripotency exit ...
# 4114  31784538  200122166  Myeloid lineage enhancers drive oncogene syner...
#
# ...

# %%
time.strftime("%Y/%m/%d %H:%M:%S", time.localtime())
# Out:
# '2022/11/09 21:19:49'

# %% [markdown]
# cell line

# %%
tmp = pd.read_csv('celllines_old.txt', sep='\t', header=None)
tmp = tmp.loc[:,1:].copy()
tmp.columns = ['name', 'status', 'comment', 'aliases']
tmp = tmp.sort_values(by='name',ignore_index=True)
tmp = tmp.dropna(subset=['name'])

# %%
l = []
for i in tmp['aliases']:
    if pd.isna(i):
        l.append(i)
    else:
        e = [i.rstrip(')').lstrip('(') for i in i.split('|')]
        # e = 
        l.append('|'.join(e))
tmp['aliases'] = l

# %%
tmp.to_csv('../celllines.txt', sep='\t', index=False)

# %%
tmp = pd.read_csv('../celllines.txt', sep='\t')

# %% [markdown]
# papers

# %%
tmp = pd.read_csv('papers_old.txt', sep='\t', header=None)
tmp = tmp.loc[:,1:].copy()
tmp.columns = ['pmid', 'unique_id', 'user_id', 'title', 'reference', 'abstract', 'pub_date', 'collect_date', 'authors', 'last_auth_email', 'journal', 'status', 'comment', 'lab', 'pub_summary']
tmp = tmp.loc[:, ['pmid', 'unique_id', 'title', 'reference', 'abstract', 'pub_date', 'collect_date', 'authors', 'last_auth_email', 'journal', 'status', 'lab', 'pub_summary', 'comment']]

# %%
journal = pd.read_csv('journals_old.txt', sep='\t', header = None, index_col=0) 
to_journal = lambda x: journal.loc[x,1]

# %%
tmp['journal'] = [to_journal(i) if not pd.isna(i) else np.nan for i in tmp['journal'] ]

# %%
tmp.to_csv('papers.txt', sep='\t', index=False)

# %% [markdown]
# cell pops

# %%
tmp = pd.read_csv('cellpops_old.txt', sep='\t', header=None)
tmp = tmp.loc[:,1:].copy()
tmp.columns = ['name', 'status', 'comment', 'aliases']
tmp = tmp.sort_values(by='name',ignore_index=True)
tmp = tmp.dropna(subset=['name'])

# %%
l = []
for i in tmp['aliases']:
    if pd.isna(i):
        l.append(i)
    else:
        e = [i.rstrip(')').lstrip('(') for i in i.split('|')]
        # e = 
        l.append('|'.join(e))
tmp['aliases'] = l

# %%
tmp.to_csv('../cellpops.txt', sep='\t', index=False)

# %% [markdown]
# cell types

# %%
tmp = pd.read_csv('celltypes_old.txt', sep='\t', header=None)
tmp = tmp.loc[:,1:].copy()
tmp.columns = ['name', 'status', 'comment', 'aliases']
tmp = tmp.sort_values(by='name',ignore_index=True)
tmp = tmp.dropna(subset=['name'])

# %%
l = []
for i in tmp['aliases']:
    if pd.isna(i):
        l.append(i)
    else:
        e = [i.rstrip(')').lstrip('(') for i in i.split('|')]
        # e = 
        l.append('|'.join(e))
tmp['aliases'] = l

# %%
tmp.to_csv('../celltypes.txt', sep='\t', index=False)

# %% [markdown]
# disease states

# %%
tmp = pd.read_csv('diseasestates_old.txt', sep='\t', header=None)
tmp = tmp.loc[:,1:].copy()
tmp.columns = ['name', 'comment', 'status', 'aliases']
tmp = tmp.loc[:,['name', 'status', 'comment', 'aliases']]
tmp = tmp.sort_values(by='name',ignore_index=True)
tmp = tmp.dropna(subset=['name'])

# %%
l = []
for i in tmp['aliases']:
    if pd.isna(i):
        l.append(i)
    else:
        e = [i.rstrip(')').lstrip('(') for i in i.split('|')]
        # e = 
        l.append('|'.join(e))
tmp['aliases'] = l

# %%
tmp.to_csv('../diseasestates.txt', sep='\t', index=False)

# %% [markdown]
# journal

# %%
tmp = pd.read_csv('journals_old.txt', sep='\t', header=None)
tmp = tmp.loc[:,1:].copy()
tmp.columns = ['name', 'issn', 'impact_factor']
tmp = tmp.sort_values(by='name',ignore_index=True)
# tmp = tmp.dropna(subset=['name'])

# %%
tmp.to_csv('journals.txt', sep='\t', index=False)

# %% [markdown]
# tissue type

# %%
tmp = pd.read_csv('tissuetypes_old.txt', sep='\t', header=None)
tmp = tmp.loc[:,1:].copy()
tmp.columns = ['name', 'status', 'comment', 'aliases']
tmp = tmp.sort_values(by='name',ignore_index=True)
# tmp = tmp.dropna(subset=['name'])

# %%
l = []
for i in tmp['aliases']:
    if pd.isna(i):
        l.append(i)
    else:
        e = [i.rstrip(')').lstrip('(') for i in i.split('|')]
        # e = 
        l.append('|'.join(e))
tmp['aliases'] = l

# %%
tmp.to_csv('../tissuetypes.txt', sep='\t', index=False)

# %%
tmp
# Out:
#                        1    2   3    4
# 0                 Cervix   ok NaN  NaN
# 1            Bone Marrow   ok NaN  NaN
# 2                  Colon   ok NaN  NaN
# 3                   Skin   ok NaN  NaN
# 4          Mammary Gland   ok NaN  NaN
# ..                   ...  ...  ..  ...
# 363           MutuI cell  new NaN  NaN
# 364       MutuI-LCL cell  new NaN  NaN
# 365  ALL xenograft cells  new NaN  NaN
# 366           mesenchyme  new NaN  NaN
# 367       cardiac tissue  new NaN  NaN
#
# [368 rows x 4 columns]
